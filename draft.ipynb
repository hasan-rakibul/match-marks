# %%
import pandas as pd

# %%
lms=pd.read_csv('gc_2023_2_COMP1002_V1_L1_A1_INT_772330_fullgc_2023-10-23-17-23-10.csv', index_col=3)

# %%
lms.head(2)
# Out:
#            Last Name First Name  Student ID
# Username
# 21471700      Abbott       Hana  21471700.0  \
# 21029918  Abdullatif      Ahmed  21029918.0
#
#           Final Mark [Total Pts: up to 0 Percentage] |954468
# Username
# 21471700                                                NaN   \
# 21029918                                                NaN
#
#           Final Grade [Total Pts: 10 Text] |954469
# Username
# 21471700                                       NaN  \
# 21029918                                       NaN
#
#           Final Mark [Total Pts: up to 70 Percentage] |1134353
# Username
# 21471700                                           52.13157     \
# 21029918                                           55.94736
#
#           Final Grade [Total Pts: 10 Text] |1134354
# Username
# 21471700                                        NaN  \
# 21029918                                        NaN
#
#          Practical 1 [Total Pts: 20 Score] |1134370
# Username
# ...

# %%
type(lms.index)
# Out:
# pandas.core.indexes.base.Index

# %%
local=pd.read_excel('DSAmarking_Semester_2_2023.xlsx', index_col=3)

# %%
local.head()
# Out:
#                                    Last Name First Name  Student ID
# Username
# 12423712                              George       Jade  12423712.0  \
# 12940606                             Tsokota     Kudzai  12940606.0
# 14030567                               Huang     Pinjie  14030567.0
# 15323598  Ahmed Abdelmuniem Abdalla Mohammed          -  15323598.0
# 17094867                                 Lam      David  17094867.0
#
#          Unnamed: 4 Practical 1   Prac1 Total   Marker             Comment
# Username
# 12423712        NaN         5555         20.0  Julian H                NaN  \
# 12940606        NaN         5555         20.0     Alvin  late sub with ext
# 14030567        NaN          NaN          NaN       NaN                NaN
# 15323598        NaN         5555         20.0    Jinguo                NaN
# 17094867        NaN          NaN          NaN       NaN                NaN
#
#          Practical 2   Prac2 Total  ... Practical 10 Prac10_Total  Marker.8
# ...

# %%
type(local.index)
# Out:
# pandas.core.indexes.base.Index

# %%
a = 'Needs Marking(0.00)'

# %%
a[14:-1]
# Out:
# '0.00'

# %%
a[:-1]
# Out:
# 'Needs Marking(20'
